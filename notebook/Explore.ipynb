# %% [markdown]
# > 探索特征的笔记。

# %%
# %pylab inline
import pandas as pd
u = pd.read_csv('../data/2nd/tianchi_mobile_recommend_train_user_filtered.csv')
i = pd.read_csv('../data/2nd/tianchi_mobile_recommend_train_item.csv', index_col=['item_id'])
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
s = u[u['behavior_type'] == 4].groupby(['date', 'item_id'])['user_id'].nunique()
s[s>1].loc['2014-12-15', :].plot(kind='bar', figsize=(8, 4))

# %%
s = u[u['behavior_type'] == 4].groupby(['date', 'item_category'])['user_id'].nunique()
s[s>1].loc['2014-12-18', :].plot(kind='bar', figsize=(15, 4))
