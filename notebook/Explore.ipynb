# %% [markdown]
# > 探索特征的笔记。

# %%
# %pylab inline
import pandas as pd
u = pd.read_csv('../data/2nd/tianchi_mobile_recommend_train_user_filtered.csv')
i = pd.read_csv('../data/2nd/tianchi_mobile_recommend_train_item.csv', index_col=['item_id'])
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
u[u.behavior_type == 4].groupby(['date'])\
.apply(lambda df: pd.Series([
            len(df[['user_id', 'item_id']].drop_duplicates()),
            len(df['user_id'].drop_duplicates()),
            len(df['item_id'].drop_duplicates())
        ], index=['(u,i)', 'i', 'u']))\
.plot(kind='bar', figsize=(15, 4));

# %%
udf = u.set_index(['user_id', 'item_id'])

# %%
u17 = udf[(udf.behavior_type == 3) & (udf.date == '2014-12-17')]

# %%
u18 = udf[(udf.behavior_type == 4) & (udf.date == '2014-12-18')]

# %%
udf18 = u[(u.date < '2014-12-18') & (u.date > '2014-12-14')].set_index(['user_id', 'item_category', 'item_id'])

# %%
udf = u.set_index(['user_id', 'item_category', 'item_id'])

# %%
udf18n = udf18.reset_index()

# %%
def inspect_user_behavior_percentage(user_id, item_category, item_id=0):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 5))
    udf18.loc[user_id, item_category, :].sort(['date', 'hour']).reset_index().groupby('item_id').size().plot(kind='pie', ax=axes[0], autopct='%.1f')
    udf18.loc[user_id, :, :].groupby(level=0).size().plot(kind='pie', ax=axes[1], autopct='%.1f')
    return udf18[udf18.behavior_type==3].loc[user_id, :, :].sort(['date', 'hour'])

# %%
u18[~u18.index.isin(u17.index)]
# Out:
#                      behavior_type user_geohash  item_category  hour  \
# user_id   item_id
# 2242451   59801863               4          NaN           3942    10
# 77443046  237749125              4          NaN           1029     0
# 29285910  171315964              4          NaN           3368    20
# 86239261  29934207               4      94n6j2j           4778    17
# 136347831 48922737               4      97kv775           5988    20
# 99785045  272357531              4          NaN           8561    11
# 126086100 184130877              4          NaN           9510    23
# 23228065  221409776              4      97jbn1f           2252    17
# 104683710 111703405              4          NaN           4778    14
# 93422967  339700377              4          NaN          12996    13
# 61664752  26078435               4          NaN          10431     8
# 99418963  366911878              4      95wig9a           3660    17
# 134496896 181217263              4          NaN          12067    15
# 116369265 221830759              4      95q61s6           5273    14
# 62320046  126902916              4          NaN          12630    22
# 47237907  68000960               4          NaN           3064    19
# 97933481  21583155               4          NaN           9614    14
# 32845489  323582185              4      ffaee9l           3660    12
# 120873    260646988              4          NaN           3064    17
# 62989173  234597767              4      96tkdfm           4228    18
# 140502795 131723630              4          NaN          11376    18
# 117597296 325637275              4          NaN           6648     4
# 18245913  345055044              4          NaN           8099    14
# 112345599 73250533               4      mtogv12           4245    20
# 98827905  125851268              4      9r5ea92           4245    11
# 72767439  213560682              4          NaN          12096     9
# 4752206   15539388               4          NaN           8561    15
# 69050200  349419654              4      9rf44h6          11376    21
# 22734359  93642440               4      9rgt2k0          10431    23
# 78574430  221197813              4      9qeq9te           4245    14
# 64471307  326130220  2014-12-18
# 80803649  235192603  2014-12-18
# 57638892  32389973   2014-12-18
# 57636921  305244702  2014-12-18
# 110659116 196108877  2014-12-18
# 73746330  237993730  2014-12-18
# 102767670 104562108  2014-12-18
# 12730285  14136232   2014-12-18
# 97974838  399458626  2014-12-18
# 59012689  180597544  2014-12-18
# 47257431  5375121    2014-12-18
# 69697214  18170459   2014-12-18
# 35603682  167074648  2014-12-18
# 110017091 132888276  2014-12-18
# 108546559 127077749  2014-12-18
# 68961612  13506760   2014-12-18
# 22874532  252996824  2014-12-18
#
# [404 rows x 5 columns]

# %%
inspect_user_behavior_percentage(2242451, 3942, 59801863)
# Out:
#                          behavior_type user_geohash  hour        date
# item_category item_id
# 3942          282999976              3      95qbjsb    17  2014-12-17

# %%
udf18n[(udf18n.item_category == 3942) & ((udf18n.item_id== 282999976) | (udf18n.item_id==59801863))].groupby('item_id').size()
# Out:
# item_id
# 59801863     8
# 282999976    7
# dtype: int64

# %%
udf18n[(udf18n.item_category == 3942)].groupby('item_id').size()
# Out:
# item_id
# 1302219       1
# 2008995       2
# 2216086       2
# 3661086       2
# 4169334       2
# 4965059       6
# 5580335       5
# 6356207       1
# 7957155       2
# 9911235       1
# 10237913     12
# 12886509      2
# 13849927      1
# 15684362      1
# 15813745     16
# 16282025      2
# 16856836      3
# 18107712      6
# 19108282      1
# 22419248     11
# 26246550      1
# 26690110      2
# 28276008      1
# 32492620      2
# 35834335     13
# 35917236      2
# 36264228      7
# 38171796      2
# 38173169      5
# 38770686      1
#              ..
# 364536002     2
# 365009814     3
# 365978782     2
# 366714787     1
# 367572080     1
# 369160490     3
# 371485218     6
# 374467373     2
# 374890725    12
# 375944970     2
# 376219845    14
# 377789749     2
# 380219851     2
# 381029427     1
# 382331577     2
# 383919580     1
# 384250084     4
# 384332103     2
# 384798433     1
# 385353005     1
# 386040162     1
# 386932195     1
# 388428231     2
# 388470592     2
# 388800953     1
# 393195634     1
# 396774231     3
# 397055863     1
# 399454553     8
# 404001148     3
# dtype: int64

# %%
u18[u18.index.isin(u17.index)]
# Out:
#                      behavior_type user_geohash  item_category  hour  \
# user_id   item_id
# 96985981  208715196              4          NaN           6648    21
# 44446177  343168939              4      94fr2e9           5533    12
# 47237907  135494766              4          NaN          11492    14
# 89380977  154226543              4          NaN          12630    23
# 72651215  316555195              4      9rgu1kq          11497     8
# 100192152 207251826              4          NaN          11597    22
# 130041655 29657299               4          NaN            198    11
# 80519771  81363321               4          NaN           7876     9
# 54949966  146829619              4          NaN          11406    11
# 138735272 319935647              4          NaN           3925    22
# 57636921  132375923              4          NaN           9614     6
# 77881862  395124703              4      mtj1906           9789     7
# 105454547 30657417               4          NaN          10662     8
# 132614903 17556221               4          NaN           6481    12
# 130041655 29657299               4          NaN            198    11
# 72651215  316555195              4      9rgu1kr          11497     8
# 5798831   265326454              4          NaN           7311    18
# 109084676 351532019              4          NaN           5480    20
# 32845489  28346734               4      ffaelme           5273    12
# 20243905  371414205              4          NaN           7939     9
# 83345819  37823257               4          NaN           3064    16
# 84676338  137655222              4      9t66q5j           8561    15
# 140502795 352340108              4          NaN           4927    11
# 138735272 81100812               4          NaN           3925    22
# 8913893   242763705              4          NaN           6417     9
# 45796530  247114107              4      ffqhkbk          12553    15
# 36863326  156641612              4          NaN           3960    10
# 139423598 192046540              4          NaN           4561    13
# 3304327   245841914              4      9roqm34           8662     7
# 84676338  113270279              4      9t66qqt           8561    15
# 33797179  307885486              4          NaN            150    14
# 4917287   84184637               4      99a3mjj          12553    10
#
#                            date
# user_id   item_id
# 96985981  208715196  2014-12-18
# 44446177  343168939  2014-12-18
# 47237907  135494766  2014-12-18
# 89380977  154226543  2014-12-18
# 72651215  316555195  2014-12-18
# 100192152 207251826  2014-12-18
# 130041655 29657299   2014-12-18
# 80519771  81363321   2014-12-18
# 54949966  146829619  2014-12-18
# 138735272 319935647  2014-12-18
# 57636921  132375923  2014-12-18
# 77881862  395124703  2014-12-18
# 105454547 30657417   2014-12-18
# 132614903 17556221   2014-12-18
# 130041655 29657299   2014-12-18
# 72651215  316555195  2014-12-18
# 5798831   265326454  2014-12-18
# 109084676 351532019  2014-12-18
# 32845489  28346734   2014-12-18
# 20243905  371414205  2014-12-18
# 83345819  37823257   2014-12-18
# 84676338  137655222  2014-12-18
# 140502795 352340108  2014-12-18
# 138735272 81100812   2014-12-18
# 8913893   242763705  2014-12-18
# 45796530  247114107  2014-12-18
# 36863326  156641612  2014-12-18
# 139423598 192046540  2014-12-18
# 3304327   245841914  2014-12-18
# 84676338  113270279  2014-12-18
# 33797179  307885486  2014-12-18
# 4917287   84184637   2014-12-18

# %%
inspect_user_behavior_percentage(4917287, 12553, 84184637)
# Out:
#                          behavior_type user_geohash  hour        date
# item_category item_id
# 12553         84184637               3          NaN    21  2014-12-17
#               207187896              3          NaN    21  2014-12-17

# %%
inspect_user_behavior_percentage(32845489, 5273, 28346734)
# Out:
#                          behavior_type user_geohash  hour        date
# item_category item_id
# 732           128875905              3      ffaeep7    18  2014-12-16
#               226973341              3      ffaelmg    18  2014-12-16
# 12630         203996381              3      ffaelo7    18  2014-12-16
# 6648          23453169               3      ffaelov    18  2014-12-16
# 12553         212384169              3      ffaee9a    18  2014-12-16
# 8744          4296732                3      ffaee97    18  2014-12-16
# 12553         173216968              3      ffaelma    18  2014-12-16
# 5273          28346734               3      ffaelo5    21  2014-12-17

# %%
i.loc[28346734]
# Out:
# item_geohash      NaN
# item_category    5273
# Name: 28346734, dtype: object

# %%
inspect_user_behavior_percentage(72651215, 11497, 316555195)
# Out:
#                          behavior_type user_geohash  hour        date
# item_category item_id
# 4245          35090837               3          NaN    13  2014-12-16
# 8662          67818190               3          NaN    15  2014-12-16
# 4245          168474683              3          NaN    15  2014-12-16
# 4677          284573126              3          NaN    15  2014-12-16
#               83734929               3      9rgu1hu    15  2014-12-16
# 5533          232877162              3          NaN    15  2014-12-16
# 4245          191055745              3      9rgu1h4    15  2014-12-16
# 11497         316555195              3          NaN     1  2014-12-17
# 10431         549285                 3          NaN     1  2014-12-17

# %%
inspect_user_behavior_percentage(32845489, 5273, 28346734)
# Out:
#                          behavior_type user_geohash  hour        date
# item_category item_id
# 732           128875905              3      ffaeep7    18  2014-12-16
#               226973341              3      ffaelmg    18  2014-12-16
# 12630         203996381              3      ffaelo7    18  2014-12-16
# 6648          23453169               3      ffaelov    18  2014-12-16
# 12553         212384169              3      ffaee9a    18  2014-12-16
# 8744          4296732                3      ffaee97    18  2014-12-16
# 12553         173216968              3      ffaelma    18  2014-12-16
# 5273          28346734               3      ffaelo5    21  2014-12-17

# %%
i.loc[28346734]
# Out:
# item_geohash      NaN
# item_category    5273
# Name: 28346734, dtype: object

# %%
inspect_user_behavior_percentage(77881862, 9789, 395124703)
# Out:
#                          behavior_type user_geohash  hour        date
# item_category item_id
# 9789          395124703              3      mtj1907    13  2014-12-17
# 8431          107216417              3      mtj0vn2    16  2014-12-17
# 9789          61841997               3      mtj0vaq    16  2014-12-17
#               25992406               3      mtj0vn9    16  2014-12-17
#               349579568              3      mtj0vko    16  2014-12-17

# %%
i.loc[349579568]
# Out:
# item_geohash      NaN
# item_category    9789
# Name: 349579568, dtype: object

# %%
udf18n[(udf18n.item_category == 9789) & ((udf18n.item_id== 349579568) | (udf18n.item_id==395124703))].groupby('item_id').size()
# Out:
# item_id
# 349579568    4
# 395124703    4
# dtype: int64

# %%
inspect_user_behavior_percentage(47237907, 11492, 135494766)
# Out:
#                          behavior_type user_geohash  hour        date
# item_category item_id
# 3397          200566462              3          NaN     1  2014-12-15
# 11492         135494766              3          NaN    22  2014-12-17
#               219019856              3          NaN    22  2014-12-17

# %%
udf18n[(udf18n.item_category == 11492) & ((udf18n.item_id== 135494766) | (udf18n.item_id==219019856))].groupby('item_id').size()
# Out:
# item_id
# 135494766    8
# 219019856    6
# dtype: int64

# %%
inspect_user_behavior_percentage(44446177, 5533, 343168939)
# Out:
#                          behavior_type user_geohash  hour        date
# item_category item_id
# 5533          343168939              3          NaN    20  2014-12-17

# %%
inspect_user_behavior_percentage(96985981, 6648, 208715196)
# Out:
#                          behavior_type user_geohash  hour        date
# item_category item_id
# 6648          182659582              3      ffolmvr    20  2014-12-17
#               208715196              3      ffolm32    20  2014-12-17

# %%
g1 = u[(u.behavior_type == 4) & (u.date == '2014-12-18')].groupby(['user_id']).item_category.nunique()
g1set = set(g1[g1>1].index)
g2 = u[(u.behavior_type == 4) & (u.date == '2014-12-17')].groupby(['user_id']).item_category.nunique()
g2set = set(g2[g2>1].index)
g1set & g2set
# Out:
# {36863326, 77443046, 84676338, 87942719, 116349225, 137531842}

# %%
u[(u.behavior_type == 4) & (u.date == '2014-12-15')].groupby(['user_id']).item_category.nunique().hist()

# %%
d = u[(u.date < '2014-12-17') & (u.date > '2014-12-13')] # 14, 15, 16

user_last_cart_hour = d[d.behavior_type == 3].groupby('user_id').hour.last()
user_cnt = d.groupby('user_id').behavior_type.sum().reset_index()
user_cnt.columns = pd.Index(['user_id', 'user_cnt'])
user_item_cnt = d.groupby(['user_id', 'item_id']).agg(dict(behavior_type='sum', item_category='first')).reset_index()
user_item_cnt.columns = pd.Index(['user_id', 'item_id', 'item_cnt', 'item_category'])
user_category_cnt = d.groupby(['user_id', 'item_category']).behavior_type.sum().reset_index()
user_category_cnt.columns = pd.Index(['user_id', 'item_category', 'category_cnt'])

usm = pd.merge(
    user_cnt,
    pd.merge(
        user_item_cnt,
        user_category_cnt,
        on=['user_id', 'item_category'], how='left'
    ),
    on='user_id'
)
usm['category_user_pcn'] = usm['category_cnt'] / usm['user_cnt']
usm['item_category_pcn'] = usm['item_cnt'] / usm['category_cnt']

# %%
usm
# Out:
#          user_id  user_cnt    item_id  item_cnt  item_category  category_cnt  \
# 0           4913       134   12265214         5           6417            41
# 1           4913       134   13017276         3           6417            41
# 2           4913       134   28137461         2           4582             9
# 3           4913       134   49377927         4           3067            11
# 4           4913       134   53738139         5           3064            11
# 5           4913       134   66149052         3           4582             9
# 6           4913       134   68000960         3           3064            11
# 7           4913       134   70376267         3          12570             7
# 8           4913       134   73870756         1           6417            41
# 9           4913       134   76478799         2           8270             2
# 10          4913       134   78219126         3           4830             6
# 11          4913       134   84593536         1           4670             2
# 12          4913       134   86683011         1           6417            41
# 13          4913       134   90525392         1           3067            11
# 14          4913       134   91060278         2           6417            41
# 15          4913       134   99542642         1           4830             6
# 16          4913       134  109195366         1           4582             9
# 17          4913       134  109947938         1           3067            11
# 18          4913       134  123292538         4           5065            19
# 19          4913       134  153620246         1           4830             6
# 20          4913       134  163999721         7           6417            41
# 21          4913       134  170754734         2           9334             4
# 22          4913       134  171297748         3           6417            41
# 23          4913       134  177505671         1           6417            41
# 24          4913       134  185126108         9           6417            41
# 25          4913       134  209034921         1           4670             2
# 26          4913       134  211808974         3           3067            11
# 27          4913       134  239168223         1           3064            11
# 28          4913       134  253347331         1          12570             7
# 29          4913       134  255563290         1           6417            41
# ...          ...       ...        ...       ...            ...           ...
# 59519  142138619         7   70531506         2           7350             6
# 59520  142138619         7   73956194         1           5320             1
# 59521  142138619         7  319508704         2           7350             6
# 59522  142138619         7  342600046         2           7350             6
# 59523  142151675        22   56508422         4           3064            18
# 59524  142151675        22  120136077         2           3064            18
# 59525  142151675        22  132877897         2            198             2
